# %%
import yfinance as yf
import pandas as pd

# %%
nifty= yf.Ticker("^NSEI")

# %%
df = nifty.history(period="max")
df.to_csv("nifty.csv")

# %%
df
# Out:
#                                    Open          High           Low  \
# Date
# 2007-09-17 00:00:00+05:30   4518.450195   4549.049805   4482.850098
# 2007-09-18 00:00:00+05:30   4494.100098   4551.799805   4481.549805
# 2007-09-19 00:00:00+05:30   4550.250000   4739.000000   4550.250000
# 2007-09-20 00:00:00+05:30   4734.850098   4760.850098   4721.149902
# 2007-09-21 00:00:00+05:30   4752.950195   4855.700195   4733.700195
# ...                                 ...           ...           ...
# 2025-06-16 00:00:00+05:30  24732.349609  24967.099609  24703.599609
# 2025-06-17 00:00:00+05:30  24977.849609  24982.050781  24813.699219
# 2025-06-18 00:00:00+05:30  24788.349609  24947.550781  24750.449219
# 2025-06-19 00:00:00+05:30  24803.250000  24863.099609  24733.400391
# 2025-06-20 00:00:00+05:30  24787.650391  25136.199219  24783.650391
#
#                                   Close  Volume  Dividends  Stock Splits
# Date
# 2007-09-17 00:00:00+05:30   4494.649902       0        0.0           0.0
# 2007-09-18 00:00:00+05:30   4546.200195       0        0.0           0.0
# 2007-09-19 00:00:00+05:30   4732.350098       0        0.0           0.0
# 2007-09-20 00:00:00+05:30   4747.549805       0        0.0           0.0
# 2007-09-21 00:00:00+05:30   4837.549805       0        0.0           0.0
# ...                                 ...     ...        ...           ...
# 2025-06-16 00:00:00+05:30  24946.500000  305800        0.0           0.0
# 2025-06-17 00:00:00+05:30  24853.400391  242400        0.0           0.0
# 2025-06-18 00:00:00+05:30  24812.050781  237600        0.0           0.0
# 2025-06-19 00:00:00+05:30  24793.250000  274600        0.0           0.0
# 2025-06-20 00:00:00+05:30  25112.400391  574700        0.0           0.0
#
# [4354 rows x 7 columns]

# %%
df.index
# Out:
# DatetimeIndex(['2007-09-17 00:00:00+05:30', '2007-09-18 00:00:00+05:30',
#                '2007-09-19 00:00:00+05:30', '2007-09-20 00:00:00+05:30',
#                '2007-09-21 00:00:00+05:30', '2007-09-24 00:00:00+05:30',
#                '2007-09-25 00:00:00+05:30', '2007-09-26 00:00:00+05:30',
#                '2007-09-27 00:00:00+05:30', '2007-09-28 00:00:00+05:30',
#                ...
#                '2025-06-09 00:00:00+05:30', '2025-06-10 00:00:00+05:30',
#                '2025-06-11 00:00:00+05:30', '2025-06-12 00:00:00+05:30',
#                '2025-06-13 00:00:00+05:30', '2025-06-16 00:00:00+05:30',
#                '2025-06-17 00:00:00+05:30', '2025-06-18 00:00:00+05:30',
#                '2025-06-19 00:00:00+05:30', '2025-06-20 00:00:00+05:30'],
#               dtype='datetime64[ns, Asia/Kolkata]', name='Date', length=4354, freq=None)

# %%
df.plot.line(y="Close", use_index =True)
# Out:
# <Axes: xlabel='Date'>

# %%
del df["Dividends"]
del df["Stock Splits"]

# %%
df["Tomorrow"] = df["Close"].shift(-1)

# %%
df
# Out:
#                                    Open          High           Low  \
# Date
# 2007-09-17 00:00:00+05:30   4518.450195   4549.049805   4482.850098
# 2007-09-18 00:00:00+05:30   4494.100098   4551.799805   4481.549805
# 2007-09-19 00:00:00+05:30   4550.250000   4739.000000   4550.250000
# 2007-09-20 00:00:00+05:30   4734.850098   4760.850098   4721.149902
# 2007-09-21 00:00:00+05:30   4752.950195   4855.700195   4733.700195
# ...                                 ...           ...           ...
# 2025-06-16 00:00:00+05:30  24732.349609  24967.099609  24703.599609
# 2025-06-17 00:00:00+05:30  24977.849609  24982.050781  24813.699219
# 2025-06-18 00:00:00+05:30  24788.349609  24947.550781  24750.449219
# 2025-06-19 00:00:00+05:30  24803.250000  24863.099609  24733.400391
# 2025-06-20 00:00:00+05:30  24787.650391  25136.199219  24783.650391
#
#                                   Close  Volume      Tomorrow
# Date
# 2007-09-17 00:00:00+05:30   4494.649902       0   4546.200195
# 2007-09-18 00:00:00+05:30   4546.200195       0   4732.350098
# 2007-09-19 00:00:00+05:30   4732.350098       0   4747.549805
# 2007-09-20 00:00:00+05:30   4747.549805       0   4837.549805
# 2007-09-21 00:00:00+05:30   4837.549805       0   4932.200195
# ...                                 ...     ...           ...
# 2025-06-16 00:00:00+05:30  24946.500000  305800  24853.400391
# 2025-06-17 00:00:00+05:30  24853.400391  242400  24812.050781
# 2025-06-18 00:00:00+05:30  24812.050781  237600  24793.250000
# 2025-06-19 00:00:00+05:30  24793.250000  274600  25112.400391
# 2025-06-20 00:00:00+05:30  25112.400391  574700           NaN
#
# [4354 rows x 6 columns]

# %%
df["Target"] = (df["Tomorrow"]>df["Close"]).astype(int)

# %%
df
# Out:
#                                    Open          High           Low  \
# Date
# 2007-09-17 00:00:00+05:30   4518.450195   4549.049805   4482.850098
# 2007-09-18 00:00:00+05:30   4494.100098   4551.799805   4481.549805
# 2007-09-19 00:00:00+05:30   4550.250000   4739.000000   4550.250000
# 2007-09-20 00:00:00+05:30   4734.850098   4760.850098   4721.149902
# 2007-09-21 00:00:00+05:30   4752.950195   4855.700195   4733.700195
# ...                                 ...           ...           ...
# 2025-06-16 00:00:00+05:30  24732.349609  24967.099609  24703.599609
# 2025-06-17 00:00:00+05:30  24977.849609  24982.050781  24813.699219
# 2025-06-18 00:00:00+05:30  24788.349609  24947.550781  24750.449219
# 2025-06-19 00:00:00+05:30  24803.250000  24863.099609  24733.400391
# 2025-06-20 00:00:00+05:30  24787.650391  25136.199219  24783.650391
#
#                                   Close  Volume      Tomorrow  Target
# Date
# 2007-09-17 00:00:00+05:30   4494.649902       0   4546.200195       1
# 2007-09-18 00:00:00+05:30   4546.200195       0   4732.350098       1
# 2007-09-19 00:00:00+05:30   4732.350098       0   4747.549805       1
# 2007-09-20 00:00:00+05:30   4747.549805       0   4837.549805       1
# 2007-09-21 00:00:00+05:30   4837.549805       0   4932.200195       1
# ...                                 ...     ...           ...     ...
# 2025-06-16 00:00:00+05:30  24946.500000  305800  24853.400391       0
# 2025-06-17 00:00:00+05:30  24853.400391  242400  24812.050781       0
# 2025-06-18 00:00:00+05:30  24812.050781  237600  24793.250000       0
# 2025-06-19 00:00:00+05:30  24793.250000  274600  25112.400391       1
# 2025-06-20 00:00:00+05:30  25112.400391  574700           NaN       0
#
# [4354 rows x 7 columns]

# %%
from sklearn.ensemble import RandomForestClassifier

model = RandomForestClassifier(n_estimators = 100,min_samples_split=100,random_state=1)
train = df.iloc[:-100]
test = df.iloc[-100:]
predictors = ["Close","Volume","Open","High","Low"]
model.fit(train[predictors],train["Target"])
# Out:
# RandomForestClassifier(min_samples_split=100, random_state=1)

# %%
from sklearn.metrics import precision_score
preds = model.predict(test[predictors])

# %%
preds = pd.Series(preds, index = test.index)

# %%
preds
# Out:
# Date
# 2025-01-23 00:00:00+05:30    1
# 2025-01-24 00:00:00+05:30    1
# 2025-01-27 00:00:00+05:30    0
# 2025-01-28 00:00:00+05:30    1
# 2025-01-29 00:00:00+05:30    1
#                             ..
# 2025-06-16 00:00:00+05:30    0
# 2025-06-17 00:00:00+05:30    1
# 2025-06-18 00:00:00+05:30    1
# 2025-06-19 00:00:00+05:30    0
# 2025-06-20 00:00:00+05:30    0
# Length: 100, dtype: int32

# %%
precision_score(test["Target"],preds)
# Out:
# 0.42592592592592593

# %%
combined = pd.concat([test["Target"],preds],axis=1)

# %%
combined.plot()
# Out:
# <Axes: xlabel='Date'>

# %%
def predict(train,test,predictions,model):
    model.fit(train[predictors],train["Target"])
    preds = model.predict(test[predictors])
    preds = pd.Series(preds, index=test.index,name="Predictions")
    combined = pd.concat([test["Target"],preds],axis=1)
    return combined

# %%
def backtest(data,model,predictors,start=2500,step=250):
    all_predictions =[]
    
    for i in range(start,data.shape[0],step):
        train = data.iloc[0:i].copy()
        test = data.iloc[i:(i+step)].copy()
        predictions = predict(train,test,predictors,model)
        all_predictions.append(predictions)
    return pd.concat(all_predictions)

# %%
predictions = backtest(df,model,predictors)

# %%
predictions["Predictions"].value_counts()
# Out:
# Predictions
# 1    1053
# 0     801
# Name: count, dtype: int64

# %%
precision_score(predictions["Target"],predictions["Predictions"])
# Out:
# 0.5327635327635327

# %%
predictions["Target"].value_counts() / predictions.
# Out:
# Target
# 1    0.543689
# 0    0.456311
# Name: count, dtype: float64

# %%
horizons = [2, 5, 60, 250, 1000]
new_predictors=[]

# %%
for horizon in horizons:
    rolling_averages = df.rolling(horizon).mean()
    ratio_column = f"Close_Ratio_{horizon}"
    df[ratio_column] = df["Close"] / rolling_averages["Close"]
    
    trend_column = f"Trend_{horizon}"
    df[trend_column] = df.shift(1).rolling(horizon).sum()["Target"]
    
    new_predictors += [ratio_column, trend_column]

# %%
df = df.dropna()

# %%
df
# Out:
#                                    Open          High           Low  \
# Date
# 2011-10-13 00:00:00+05:30   5130.799805   5136.950195   5067.649902
# 2011-10-14 00:00:00+05:30   5057.350098   5141.399902   5056.600098
# 2011-10-17 00:00:00+05:30   5156.200195   5160.200195   5084.500000
# 2011-10-18 00:00:00+05:30   5049.450195   5057.500000   5011.049805
# 2011-10-19 00:00:00+05:30   5080.450195   5148.049805   5075.299805
# ...                                 ...           ...           ...
# 2025-06-13 00:00:00+05:30  24473.000000  24754.349609  24473.000000
# 2025-06-16 00:00:00+05:30  24732.349609  24967.099609  24703.599609
# 2025-06-17 00:00:00+05:30  24977.849609  24982.050781  24813.699219
# 2025-06-18 00:00:00+05:30  24788.349609  24947.550781  24750.449219
# 2025-06-19 00:00:00+05:30  24803.250000  24863.099609  24733.400391
#
#                                   Close  Volume      Tomorrow  Target  \
# Date
# 2011-10-13 00:00:00+05:30   5077.850098       0   5132.299805       1
# 2011-10-14 00:00:00+05:30   5132.299805       0   5118.250000       0
# 2011-10-17 00:00:00+05:30   5118.250000       0   5037.500000       0
# 2011-10-18 00:00:00+05:30   5037.500000       0   5139.149902       1
# 2011-10-19 00:00:00+05:30   5139.149902       0   5091.899902       0
# ...                                 ...     ...           ...     ...
# 2025-06-13 00:00:00+05:30  24718.599609  318700  24946.500000       1
# 2025-06-16 00:00:00+05:30  24946.500000  305800  24853.400391       0
# 2025-06-17 00:00:00+05:30  24853.400391  242400  24812.050781       0
# 2025-06-18 00:00:00+05:30  24812.050781  237600  24793.250000       0
# 2025-06-19 00:00:00+05:30  24793.250000  274600  25112.400391       1
#
#                            Close_Ratio_2  Trend_2  Close_Ratio_5  Trend_5  \
# Date
# 2011-10-13 00:00:00+05:30       0.997883      1.0       1.014789      3.0
# 2011-10-14 00:00:00+05:30       1.005333      1.0       1.015754      3.0
# 2011-10-17 00:00:00+05:30       0.998629      1.0       1.007444      2.0
# 2011-10-18 00:00:00+05:30       0.992049      0.0       0.989091      2.0
# 2011-10-19 00:00:00+05:30       1.009989      1.0       1.007477      2.0
# ...                                  ...      ...            ...      ...
# 2025-06-13 00:00:00+05:30       0.996581      0.0       0.989095      3.0
# 2025-06-16 00:00:00+05:30       1.004589      1.0       0.999468      3.0
# 2025-06-17 00:00:00+05:30       0.998131      1.0       0.997743      2.0
# 2025-06-18 00:00:00+05:30       0.999167      0.0       0.998724      1.0
# 2025-06-19 00:00:00+05:30       0.999621      0.0       0.998731      1.0
#
#                            Close_Ratio_60  Trend_60  Close_Ratio_250  \
# Date
# 2011-10-13 00:00:00+05:30        0.992330      23.0         0.911365
# 2011-10-14 00:00:00+05:30        1.004393      24.0         0.921801
# 2011-10-17 00:00:00+05:30        1.003264      23.0         0.919921
# 2011-10-18 00:00:00+05:30        0.989147      23.0         0.906187
# 2011-10-19 00:00:00+05:30        1.010438      24.0         0.925163
# ...                                   ...       ...              ...
# 2025-06-13 00:00:00+05:30        1.025234      35.0         1.024795
# 2025-06-16 00:00:00+05:30        1.032945      35.0         1.033955
# 2025-06-17 00:00:00+05:30        1.027659      34.0         1.029835
# 2025-06-18 00:00:00+05:30        1.024604      33.0         1.027881
# 2025-06-19 00:00:00+05:30        1.022700      32.0         1.026876
#
#                            Trend_250  Close_Ratio_1000  Trend_1000
# Date
# 2011-10-13 00:00:00+05:30      111.0          1.042939       510.0
# 2011-10-14 00:00:00+05:30      111.0          1.053995       510.0
# 2011-10-17 00:00:00+05:30      111.0          1.051026       509.0
# 2011-10-18 00:00:00+05:30      110.0          1.034383       508.0
# 2011-10-19 00:00:00+05:30      111.0          1.055190       508.0
# ...                              ...               ...         ...
# 2025-06-13 00:00:00+05:30      128.0          1.245760       537.0
# 2025-06-16 00:00:00+05:30      128.0          1.256643       537.0
# 2025-06-17 00:00:00+05:30      127.0          1.251369       536.0
# 2025-06-18 00:00:00+05:30      126.0          1.248707       536.0
# 2025-06-19 00:00:00+05:30      125.0          1.247182       535.0
#
# [3353 rows x 17 columns]

# %%
model = RandomForestClassifier(n_estimators=200, min_samples_split=50, random_state=1)

# %%
def predict(train,test,predictions,model):
    model.fit(train[predictors],train["Target"])
    preds = model.predict_proba(test[predictors])[:,-1]
    preds[preds >= .6] = 1
    preds[preds <.6] =0 
    preds = pd.Series(preds, index=test.index,name="Predictions")
    combined = pd.concat([test["Target"],preds],axis=1)
    return combined

# %%
predictions = backtest(df,model,new_predictors)

# %%
predictions["Predictions"].value_counts()
# Out:
# Predictions
# 0.0    711
# 1.0    142
# Name: count, dtype: int64

# %%
precision_score(predictions["Target"],predictions["Predictions"])
# Out:
# 0.528169014084507
